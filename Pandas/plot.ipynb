# %%
import pandas as pd 
import numpy as np

# %%
penguins = pd.read_csv("data/penguins.csv")

# %%
list(penguins.columns)
# Out:
# ['species',
#  'island',
#  'bill_length_mm',
#  'bill_depth_mm',
#  'flipper_length_mm',
#  'body_mass_g',
#  'sex']

# %%
penguins['body_mass_g'].plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
penguins['bill_length_mm'].plot(kind="hist", color="gray")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
penguins['bill_depth_mm'].plot(kind="hist", color="orange")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
penguins['species'].value_counts().plot(kind="bar", color="blue")
# Out:
# <AxesSubplot:>

# %%
penguins['island'].value_counts().plot(kind="bar", color=["brown", "green", "gold"])
# Out:
# <AxesSubplot:>

# %%
penguins[['species', 'island']].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='species,island'>

# %%
penguins[["bill_length_mm", "bill_depth_mm"]].plot(x="bill_length_mm", y="bill_depth_mm", kind="scatter")
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='bill_depth_mm'>
